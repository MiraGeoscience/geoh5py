# %%
# Create a new project
from geoh5py.workspace import Workspace

# %%
testgh5 = Workspace(r'H:\GDP00022\GOCAD\SA_Solid_Geology.geoh5')  #container of original GOCAD TS surfaces

# %%
testgh5

# %%
testgh5.all_objects()

# %%
testgh5.all_data()

# %%
testgh5.all_types()

# %%
for x in testgh5.all_objects():
    print(x.uid, x.cells.shape,x.vertices.shape)
# Out:
# 029bf205-b2a1-4f99-ac97-aa93d1cb444a (45410, 3) (23021, 3)
# 04f42664-5075-4a5d-bdd3-95705f026443 (22026, 3) (11015, 3)
# 07e3cc13-9101-4410-9c9d-95c61ead9091 (8923, 3) (5076, 3)
# 09d133e9-7757-4a88-af49-45bd0581738f (38272, 3) (19142, 3)
# 0e2357a9-ad39-4f08-99b4-d2de57633394 (20532, 3) (10271, 3)
# 158dcc49-407f-4b0f-ba6f-e68548d02f17 (12954, 3) (6479, 3)
# 19842652-6870-489d-80ee-29edfea8c94d (27064, 3) (13534, 3)
# 1d1783c8-b436-4a62-a5df-a659f0785432 (92760, 3) (46388, 3)
# 21c2ef80-f2ef-46b7-9b38-8b7cade94b1b (4864, 3) (2436, 3)
# 21c53d7d-55c7-45bf-99dd-7a0cc7f0f02d (163530, 3) (81773, 3)
# 22c5885a-3131-4eec-b29b-febb84a6f4c1 (75086, 3) (37563, 3)
# 27078df0-3a8c-49a3-aa57-c00203ff5735 (32258, 3) (16131, 3)
# 2a8bb4a0-cb68-4ebc-ad46-772b2dba87db (465828, 3) (242692, 3)
# 2e123f30-3806-4525-9cde-d58435bf04a8 (81670, 3) (40895, 3)
# 2f37f8b6-010e-4f5c-8fa3-6c5c48dd59b4 (58214, 3) (29131, 3)
# 31bfcd0f-a1e3-4133-a2e5-5ea2105359c5 (403314, 3) (201695, 3)
# ...

# %%
testobj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8e8b9a93858a> in <module>
# ----> 1 testobj
#
# NameError: name 'testobj' is not defined
